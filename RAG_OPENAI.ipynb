# %%
# !pip install -r "requirements.txt"
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (0.3.14)
# Requirement already satisfied: pinecone in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (5.4.2)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (0.3.14)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (3.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (0.3.29)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (0.2.10)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain->-r requirements.txt (line 1)) (9.0.0)
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (2024.12.14)
# Requirement already satisfied: pinecone-plugin-inference<4.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from pinecone->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from langchain-community->-r requirements.txt (line 3)) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->-r requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community->-r requirements.txt (line 3)) (2.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (4.47.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (0.27.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers->-r requirements.txt (line 4)) (11.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 1)) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 3)) (3.25.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 4)) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 4)) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.29->langchain->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 1)) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->-r requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.5.3->pinecone->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 1)) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (12.6.85)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 4)) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 4)) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers->-r requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers->-r requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain->-r requirements.txt (line 1)) (1.3.1)

# %%
#Libraries
import os
import time
import warnings
warnings.filterwarnings('ignore')
from google.colab import userdata

# %%
#Langchain and it's components
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.chains import RetrievalQA

# %%
#Data Ingestion
loader = TextLoader("/content/OpenAI.txt")
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '/content/OpenAI.txt'}, page_content='OpenAI is an artificial intelligence research and deployment company founded in December 2015 by Elon Musk, Sam Altman, Greg Brockman, Ilya Sutskever, Wojciech Zaremba, and others, with the mission to ensure that artificial general intelligence (AGI) benefits all of humanity. Its goal is to develop safe and beneficial AI while making its access widespread, focusing on advancing AGI responsibly and in ways that benefit society. OpenAI is known for developing innovative technologies such as the GPT (Generative Pre-trained Transformer) series, which can generate human-like text for applications in writing, coding, customer support, education, and more. It also created DALL·E for generating images from textual descriptions, Codex for understanding and generating programming code, and Whisper for automatic speech recognition. Initially a nonprofit organization, OpenAI transitioned to a "capped-profit" model to secure funding for its ambitious AI research, partnering with Microsoft, which invested billions into the company and integrated OpenAI models into products like Azure OpenAI Service and Microsoft 365\'s Copilot. OpenAI emphasizes ethical AI development, prioritizing safety, alignment with human values, and preventing misuse, while engaging with policymakers and the public to ensure transparent and responsible AI advancements. Its API allows developers to integrate AI models into applications for tasks such as chatbots, text summarization, and translation. Recent developments include advancements in the GPT-4.5 and GPT-5 series, improved AI reasoning, and continued collaboration with major tech companies, alongside efforts to enhance interpretability and safety in AI systems.')]

# %%
#Splitting the data
text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=0)

# %%
text=text_splitter.split_documents(documents)
text
# Out:
# [Document(metadata={'source': '/content/OpenAI.txt'}, page_content='OpenAI is an artificial intelligence research and deployment company founded in December 2015 by Elon Musk, Sam Altman, Greg Brockman, Ilya Sutskever, Wojciech Zaremba, and others, with the mission to ensure that artificial general intelligence (AGI) benefits all of humanity. Its goal is to develop safe and beneficial AI while making its access widespread, focusing on advancing AGI responsibly and in ways that benefit society. OpenAI is known for developing innovative technologies such as the GPT (Generative Pre-trained Transformer) series, which can generate human-like text for applications in writing, coding, customer support, education, and more. It also created DALL·E for generating images from textual descriptions, Codex for understanding and generating programming code, and Whisper for automatic speech recognition. Initially a nonprofit organization, OpenAI transitioned to a "capped-profit" model to secure funding for its ambitious AI research, partnering with Microsoft, which invested billions into the company and integrated OpenAI models into products like Azure OpenAI Service and Microsoft 365\'s Copilot. OpenAI emphasizes ethical AI development, prioritizing safety, alignment with human values, and preventing misuse, while engaging with policymakers and the public to ensure transparent and responsible AI advancements. Its API allows developers to integrate AI models into applications for tasks such as chatbots, text summarization, and translation. Recent developments include advancements in the GPT-4.5 and GPT-5 series, improved AI reasoning, and continued collaboration with major tech companies, alongside efforts to enhance interpretability and safety in AI systems.')]

# %%
#Embedding
embeddings = HuggingFaceEmbeddings()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#DB Setup
from pinecone import Pinecone, ServerlessSpec

# %%
##Building connection with DB
pc = Pinecone(api_key='pcsk_3ViMpX_5Nzyz3WSo9NqdvUdkGrBA8DZQgoYW56Uuyg7jqgLBEsB39aAzgBzC276oeJsTqy', environment="us-east-1")

# %%
#setting up server
cloud = 'aws'
region = 'us-east-1'
server = ServerlessSpec(cloud=cloud,region=region)

# %%
#Database Creation
name_of_database = 'rag-app-2'

# %%
# checking whether there is a existing database with the name
if name_of_database not in pc.list_indexes().names():
  # We can create our database
  pc.create_index(
      name = name_of_database,
      dimension = 768,
      metric = "cosine",
      spec = server,
  )


  # taking a confirmation that our database is created or not
  while not pc.describe_index(name_of_database).status["ready"]:
    time.sleep(1)

print(pc.Index(name_of_database).describe_index_stats())
# Out:
# {'dimension': 768,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# pc.describe_index(name_of_database): Retrieves details about the specified database.
#
# .status["ready"]: Checks whether the database is ready for use.
#
# while not: This loop ensures that the script waits until the database is fully initialized and ready.
#
# time.sleep(1): Introduces a delay of 1 second between checks to avoid overwhelming the server with frequent requests.

# %%
#Adding the data into our vectorStore
from langchain.vectorstores import Pinecone

# %%
os.environ["PINECONE_API_KEY"]=userdata.get("Pinecone_Token")

# %%
if name_of_database not in pc.list_indexes():
  textsearch = Pinecone.from_documents(text,embeddings,index_name=name_of_database)
else:
  textsearch = Pinecone.from_existing_index(name_of_database,embeddings,pinecone_index=pc.Index(name_of_database))

# %% [markdown]
# Model Setup

# %%
#https://huggingface.co/openai-community/gpt2

# %%
repo = "openai-community/gpt2"

# %%
from langchain.llms import HuggingFaceHub

# %%
#Model Initialize
model = HuggingFaceHub(repo_id=repo,huggingfacehub_api_token=userdata.get("MyToken1"))

# %%
model
# Out:
# HuggingFaceHub(client=<InferenceClient(model='openai-community/gpt2', timeout=None)>, repo_id='openai-community/gpt2', task='text-generation', huggingfacehub_api_token='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')

# %%
#Prompting
from langchain.prompts import PromptTemplate

# %%
template = """You are a helpful assistant. Answer the following question concisely:
Context: {context}
Questions: {question}
Helpful Answer:"""

# %%
prompt = PromptTemplate(template=template, input_variables=["context", "question"])

# %%
#Chaining
chain=RetrievalQA.from_chain_type(llm=model,
                                retriever=textsearch.as_retriever())

# %%
chain
# Out:
# RetrievalQA(verbose=False, combine_documents_chain=StuffDocumentsChain(verbose=False, llm_chain=LLMChain(verbose=False, prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n{context}\n\nQuestion: {question}\nHelpful Answer:"), llm=HuggingFaceHub(client=<InferenceClient(model='openai-community/gpt2', timeout=None)>, repo_id='openai-community/gpt2', task='text-generation', huggingfacehub_api_token='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'), output_parser=StrOutputParser(), llm_kwargs={}), document_prompt=PromptTemplate(input_variables=['page_content'], input_types={}, partial_variables={}, template='{page_content}'), document_variable_name='context'), retriever=VectorStoreRetriever(tags=['Pinecone', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.pinecone.Pinecone object at 0x7992aa2b3f10>, search_kwargs={}))

# %%
query = "What is OpenAI?"

# %%
results=chain.run(query)
results
# Out:
# 'Use the following pieces of context to answer the question at the end. If you don\'t know the answer, just say that you don\'t know, don\'t try to make up an answer.\n\nOpenAI is an artificial intelligence research and deployment company founded in December 2015 by Elon Musk, Sam Altman, Greg Brockman, Ilya Sutskever, Wojciech Zaremba, and others, with the mission to ensure that artificial general intelligence (AGI) benefits all of humanity. Its goal is to develop safe and beneficial AI while making its access widespread, focusing on advancing AGI responsibly and in ways that benefit society. OpenAI is known for developing innovative technologies such as the GPT (Generative Pre-trained Transformer) series, which can generate human-like text for applications in writing, coding, customer support, education, and more. It also created DALL·E for generating images from textual descriptions, Codex for understanding and generating programming code, and Whisper for automatic speech recognition. Initially a nonprofit organization, OpenAI transitioned to a "capped-profit" model to secure funding for its ambitious AI research, partnering with Microsoft, which invested billions into the company and integrated OpenAI models into products like Azure OpenAI Service and Microsoft 365\'s Copilot. OpenAI emphasizes ethical AI development, prioritizing safety, alignment with human values, and preventing misuse, while engaging with policymakers and the public to ensure transparent and responsible AI advancements. Its API allows developers to integrate AI models into applications for tasks such as chatbots, text summarization, and translation. Recent developments include advancements in the GPT-4.5 and GPT-5 series, improved AI reasoning, and continued collaboration with major tech companies, alongside efforts to enhance interpretability and safety in AI systems.\n\nQuestion: What is OpenAI?\nHelpful Answer: OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenAI Foundation and the OpenAI Foundation, a nonprofit organization that is dedicated to advancing the advancement of AI. OpenAI is a collaborative effort between the OpenA ...
